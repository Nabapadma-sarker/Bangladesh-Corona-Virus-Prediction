# %%
from lxml import html
import requests
import numpy as np
import pandas as pd

page = requests.get('https://www.worldometers.info/coronavirus/news-block/news_main_updates.php?fd=lm_2020-06-08&country=BGD&region=%27%27&days_count=300')
tree = html.fromstring(page.content)

# %%
newCase = [];
newDeath = [];
#This will create a list of cases:
cases = tree.xpath('//div[@class="newsdate_div"]/*')
dates = tree.xpath('//div[@class="newsdate_div"]/@id')
#newCase = html.tostring(page.text)
#newCase = tree.xpath('//li[@class="news_li"]/strong[contains(.,"new cases")]/text()')
#newDeath = tree.xpath('//li[@class="news_li"]/strong[contains(.,"new deaths")]/text()')
#for i in cases:
#    newCase.append(i.replace("new cases", "").strip())
#    newDeath.append(i.replace("new deaths", "").strip())
#pd.DataFrame(cases).to_csv("data1.csv")
#dates = tree.xpath('//button')[0]
#dates = tree.xpath('//button[@class="btn btn-light date-btn"]/@data-date')
#dates = tree.getroot()
# creating a blank series 
#singledataset = pd.Series([]) 
singledataset = pd.DataFrame(columns=['date','new cases','new deaths'])
i=1
j=0
singledata = pd.Series(data=['0','0','0'], index=singledataset.columns) 
for row in cases:
    if i%2==0:        
        print(dates[j].lstrip("newsdate"))
        
        #print(j)
        singledata[0] = dates[j].lstrip("newsdate")
        for deathcase in row.findall('.//strong'):
               #if eathcase.find("new cases"):
                #singledataset.append(deathcase.text)
               #print(deathcase.text)
                #print(type(deathcase.text))
                NoneType = type(None)
                #x = None
                #print(type(deathcase.text))
                if type(deathcase.text) == NoneType:
                    continue
                #print(deathcase.text)
                #singledataset.append(deathcase.text)
                #print(deathcase.text.find("deaths"))                    
                if (deathcase.text.find("new cases") != -1):
                    y = deathcase.text.rstrip("new cases")
                    singledata[1] = y
                    print(y)
                    
                if (deathcase.text.find("new deaths") != -1):
                    x = deathcase.text.rstrip("new deaths")
                    singledata[2] = x
                    print(x)
        j+=1
        #print(j)
        print(singledata)
        #print(singledataset)
        #print(singledataset.dtypes)
        singledataset.loc[j] = singledata
        #df.insert(loc=j, columns=['date','new cases','new deaths'],singledata))
        #print(singledataset.columns)
        #print(singledataset.to_numpy())
        #singledataset.append(singledata)
        #print(singledataset.dtypes)
        singledata=pd.Series(data=['0','0','0'], index=singledataset.columns)  
        #singledataset[1] = '0'
        #singledataset[2] = '0'
    i+=1
    #print(row.getparent())
    #print(row.xpath('//strong[contains(.,"new cases")]/text()'))
    #print(row.xpath('//strong[contains(.,"new deaths")]/text()'))
    #a  = row.Element(li)
    #tree3 = row.ElementTree(a)
    #print(tree3)
    #print(html.tostring(row.findall(".//strong")))
#print(cases)
#tree2 = html.parse(page.text)
#print(page)
#print(tree2)
#print(newDeath)
#print(dates)
#print(len(cases))
#len(dates)*2
# Out:
# 2020-06-07
# 2,743
# 42
# date          2020-06-07
# new cases          2,743
# new deaths            42
# dtype: object
# 2020-06-06
# 2,635
# 35
# date          2020-06-06
# new cases          2,635
# new deaths            35
# dtype: object
# 2020-06-05
# 2,828
# 30
# date          2020-06-05
# new cases          2,828
# new deaths            30
# dtype: object
# 2020-06-04
# 2,423
# 35
# date          2020-06-04
# new cases          2,423
# new deaths            35
# dtype: object
# 2020-06-03
# 2,695
# 37
# date          2020-06-03
# new cases          2,695
# new deaths            37
# dtype: object
# 2020-06-02
# 2,911
# 37
# date          2020-06-02
# new cases          2,911
# new deaths            37
# dtype: object
# 2020-06-01
# 2,381
# 22
# date          2020-06-01
# new cases          2,381
# new deaths            22
# dtype: object
# 2020-05-31
# 2,545
# 40
# date          2020-05-31
# new cases          2,545
# new deaths            40
# dtype: object
# 2020-05-30
# ...

# %%
print(singledataset)
# Out:
#           date new cases new deaths
# 1   2020-06-07     2,743         42
# 2   2020-06-06     2,635         35
# 3   2020-06-05     2,828         30
# 4   2020-06-04     2,423         35
# 5   2020-06-03     2,695         37
# ..         ...       ...        ...
# 77  2020-03-21         4          0
# 78  2020-03-20         2          0
# 79  2020-03-19         4          0
# 80  2020-03-18         4          0
# 81  2020-03-16         3          0
#
# [81 rows x 3 columns]
