# %%
from lxml import html
import requests
import pandas as pd

page = requests.get('https://www.worldometers.info/coronavirus/news-block/news_main_updates.php?fd=lm_2020-06-06&country=BGD&region=%27%27&days_count=300')
tree = html.fromstring(page.content)

# %%
from html.parser import HTMLParser
from html.entities import name2codepoint

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Start tag:", tag)
        for attr in attrs:
            print("     attr:", attr)
    def handle_endtag(self, tag):
        print("End tag  :", tag)
    def handle_data(self, data):
        print("Data     :", data)
    def handle_comment(self, data):
        print("Comment  :", data)
    def handle_entityref(self, name):
        c = chr(name2codepoint[name])
        print("Named ent:", c)
    def handle_charref(self, name):
        if name.startswith('x'):
            c = chr(int(name[1:], 16))
        else:
            c = chr(int(name))
        print("Num ent  :", c)
    def handle_decl(self, data):
        print("Decl     :", data)

parser = MyHTMLParser()
parser.feed(page.text)
# Out:
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-06-04')
# Data     : June 4
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-06-04')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 2,423 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 35 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8525/news/Bangladesh%E2%80%99s-coronavirus-cases-jump-by-2423')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-06-03')
# Data     : June 3
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-06-03')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 2,695 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 37 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8499/news/Bangladesh-confirms-37-more-coronavirus-deaths-2695-new-cases')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-06-02')
# Data     : June 2
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-06-02')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 2,911 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 37 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8471/news/Coronavirus-cases-leap-by-record-2911-in-Bangladesh')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-06-01')
# Data     : June 1
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-06-01')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 2,381 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 22 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8443/news/Coronavirus-Bangladesh-confirms-22-more-deaths-2381-new-cases')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-31')
# Data     : May 31
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-31')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 2,545 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 40 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://iedcr.gov.bd/')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-30')
# Data     : May 30
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-30')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 1,764 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 28 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8382/news/Bangladesh-reports-highest-28-deaths-from-coronavirus-in-a-day')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-29')
# Data     : May 29
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-29')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 2,523 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 23 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://iedcr.gov.bd/')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-28')
# Data     : May 28
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-28')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 2,029 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 15 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8327/news/Bangladesh%E2%80%99s-daily-coronavirus-cases-hit-2000-for-the-first-time')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-27')
# Data     : May 27
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-27')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 1,541 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 22 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8303/news/Bangladesh%E2%80%99s-coronavirus-cases-jump-by-1541-22-new-deaths-reported')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-26')
# Data     : May 26
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-26')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 1,166 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 21 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8274/news/Bangladesh-confirms-21-more-coronavirus-deaths-1166-new-cases')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-25')
# Data     : May 25
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-25')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 1,975 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 21 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8252/news/Bangladesh-sees-highest-rise-in-coronavirus-cases-1')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-24')
# Data     : May 24
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-24')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 1,532 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 28 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8224/news/Bangladesh-reports-record-28-deaths-from-coronavirus-in-24-hours')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-23')
# Data     : May 23
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-23')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 1,873 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 20 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8193/news/Bangladesh-sees-highest-rise-in-coronavirus-cases')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-22')
# Data     : May 22
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-22')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 1,694 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 24 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8162/news/Bangladesh%E2%80%99s-daily-virus-death-toll-hits-record-high')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-21')
# Data     : May 21
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-21')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 1,773 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 22 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8135/news/Bangladesh-sees-highest-daily-rise-in-cases-deaths')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-20')
# Data     : May 20
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-20')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 1,617 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 16 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8104/news/Coronavirus-cases-in-Bangladesh-see-biggest-jump-by-1617')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-19')
# Data     : May 19
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-19')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 1,251 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 21 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8081/news/Coronavirus-Bangladesh-confirms-21-more-deaths-1251-new-cases-2')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05-18')
# Data     : May 18
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-05-18')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 1,602 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 21 new deaths
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://en.somoynews.tv/8052/news/Coronavirus-Bangladesh-sees-deadliest-day-1')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-05

# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-03-18')
# Data     : March 18
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-03-18')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: img
#      attr: ('alt', 'alert')
#      attr: ('src', '/images/alert.png')
#      attr: ('style', 'width: 16px;')
# End tag  : img
# Data     :
# Start tag: strong
# Data     : 4 new cases
# End tag  : strong
# Data     :  and
# Start tag: strong
# Data     : 1 new death
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     : : 1
# Start tag: sup
# Data     : st
# End tag  : sup
# Data     :  death
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://unb.com.bd/category/Bangladesh/bangladesh-reports-first-coronavirus-death/47361')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Start tag: button
#      attr: ('style', 'margin-top:30px;')
#      attr: ('class', 'btn btn-light date-btn')
#      attr: ('data-date', '2020-03-16')
# Data     : March 16
# Start tag: i
#      attr: ('class', 'fa fa-chevron-circle-down')
# End tag  : i
# End tag  : button
# Start tag: div
#      attr: ('class', 'newsdate_div')
#      attr: ('style', 'display: none;')
#      attr: ('id', 'newsdate2020-03-16')
# Start tag: span
#      attr: ('id', 'updates')
#      attr: ('class', 'news_category_title')
# Data     : Updates
# End tag  : span
# Start tag: div
#      attr: ('class', 'news_post')
# Data     :
#
# Start tag: div
#      attr: ('class', 'news_body')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'news_ul')
# Start tag: li
#      attr: ('class', 'news_li')
# Start tag: strong
# Data     : 3 new cases
# End tag  : strong
# Data     :  in
# Start tag: strong
# Start tag: a
#      attr: ('style', 'text-decoration: underline;')
#      attr: ('href', '/coronavirus/country/bangladesh/')
# Data     : Bangladesh
# End tag  : a
# End tag  : strong
# Data     : . a ban on entry from Europe and several other countries, including India, goes into effect today at midnight and will last for at last 16 days
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://www.dhakatribune.com/bangladesh/2020/03/16/3-more-cases-of-coronavirus-confirmed-in-bangladesh')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# Data     :
# Start tag: span
#      attr: ('class', 'source')
# Data     : [
# Start tag: a
#      attr: ('class', 'news_source_a')
#      attr: ('target', '_blank')
#      attr: ('href', 'https://www.devdiscourse.com/article/international/938615-coronavirus-bangladesh-to-ban-travellers-entry-from-europe-several-countries-including-india')
# Data     : source
# End tag  : a
# Data     : ]
# End tag  : span
# End tag  : li
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# End tag  : div
# Comment  : -------- close date -------
# Data     :
#
#
# Start tag: div
#      attr: ('style', 'width:100%; text-align:center;margin: 0 auto;')
# Data     :
#
# Start tag: a
#      attr: ('style', 'display: none;')
#      attr: ('href', 'javascript:void(0)')
#      attr: ('class', 'load-more__btn')
#      attr: ('data-country', 'BGD')
#      attr: ('data-country', 'BGD')
#      attr: ('data-days_count', '300')
#      attr: ('id', 'lm_2020-03-16')
# Start tag: button
#      attr: ('class', 'btn')
# Data     : View More News
# Start tag: img
#      attr: ('alt', 'view more')
#      attr: ('style', 'width:16px;')
#      attr: ('src', 'data:image/png;base64,...')
# End tag  : img
# End tag  : button
# End tag  : a
# Data     :
#
#
#
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('style', 'width:100%;text-align:center; ')
# Data     :
#
# Start tag: div
#      attr: ('style', 'display: none;')
#      attr: ('class', 'loading lds-ellipsis')
# Data     :
#
# Start tag: div
# End tag  : div
# Data     :
#
# Start tag: div
# End tag  : div
# Data     :
#
# Start tag: div
# End tag  : div
# Data     :
#
# Start tag: div
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
# Comment  :  news block
# Data     :

# %%
newCase = [];
newDeath = [];
#This will create a list of cases:
cases = tree.xpath('//div[@class="newsdate_div"]/*')
dates = tree.xpath('//div[@class="newsdate_div"]/@id')
#newCase = html.tostring(page.text)
#newCase = tree.xpath('//li[@class="news_li"]/strong[contains(.,"new cases")]/text()')
#newDeath = tree.xpath('//li[@class="news_li"]/strong[contains(.,"new deaths")]/text()')
#for i in cases:
#    newCase.append(i.replace("new cases", "").strip())
#    newDeath.append(i.replace("new deaths", "").strip())
#pd.DataFrame(cases).to_csv("data1.csv")
#dates = tree.xpath('//button')[0]
#dates = tree.xpath('//button[@class="btn btn-light date-btn"]/@data-date')
#dates = tree.getroot()
i=1
j=0
for row in cases:
    if i%2==0:
        print(dates[j])
        for deathcase in row.findall('.//strong'):
               print(deathcase.text)
               #if deathcase.find("new cases"):
               #print(deathcase.text)
        j+=1
    i+=1
    #print(row.getparent())
    #print(row.xpath('//strong[contains(.,"new cases")]/text()'))
    #print(row.xpath('//strong[contains(.,"new deaths")]/text()'))
    #a  = row.Element(li)
    #tree3 = row.ElementTree(a)
    #print(tree3)
    #print(html.tostring(row.findall(".//strong")))
#print(cases)
#tree2 = html.parse(page.text)
#print(page)
#print(tree2)
#print(newDeath)
#print(dates)
#print(len(cases))
#len(dates)*2
# Out:
# newsdate2020-06-04
# 2,423 new cases
# 35 new deaths
# None
# newsdate2020-06-03
# 2,695 new cases
# 37 new deaths
# None
# newsdate2020-06-02
# 2,911 new cases
# 37 new deaths
# None
# newsdate2020-06-01
# 2,381 new cases
# 22 new deaths
# None
# newsdate2020-05-31
# 2,545 new cases
# 40 new deaths
# None
# newsdate2020-05-30
# 1,764 new cases
# 28 new deaths
# None
# newsdate2020-05-29
# 2,523 new cases
# 23 new deaths
# None
# newsdate2020-05-28
# 2,029 new cases
# 15 new deaths
# None
# newsdate2020-05-27
# 1,541 new cases
# 22 new deaths
# None
# newsdate2020-05-26
# 1,166 new cases
# 21 new deaths
# None
# newsdate2020-05-25
# 1,975 new cases
# 21 new deaths
# None
# newsdate2020-05-24
# 1,532 new cases
# 28 new deaths
# None
# newsdate2020-05-23
# 1,873 new cases
# 20 new deaths
# None
# newsdate2020-05-22
# 1,694 new cases
# 24 new deaths
# None
# newsdate2020-05-21
# 1,773 new cases
# 22 new deaths
# None
# newsdate2020-05-20
# 1,617 new cases
# 16 new deaths
# None
# newsdate2020-05-19
# 1,251 new cases
# 21 new deaths
# None
# newsdate2020-05-18
# 1,602 new cases
# 21 new deaths
# None
# newsdate2020-05-17
# 1,273 new cases
# 14 new deaths
# None
# newsdate2020-05-16
# 930 new cases
# 16 new deaths
# None
# newsdate2020-05-15
# 1,202 new cases
# 15 new deaths
# None
# newsdate2020-05-14
# 1,041 new cases
# 14 new deaths
# None
# newsdate2020-05-13
# 1,162 new cases
# 19 new deaths
# None
# newsdate2020-05-12
# 969 new cases
# 11 new deaths
# None
# newsdate2020-05-11
# 1,034 new cases
# 11 new deaths
# None
# newsdate2020-05-10
# 887 new cases
